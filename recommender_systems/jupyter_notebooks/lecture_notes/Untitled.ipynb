# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from numpy.random import rand
from sklearn.metrics.pairwise import euclidean_distances
import numpy.linalg as npla
from math import sqrt
from pprint import pprint
import random

# %%
fashion_df = pd.read_csv("datasets/fashion/all_mix.csv")
fashion_dat = ['id', 'gender', 'masterCategory', 'subCategory', 'articleType', 'baseColour', 'season', 'year',
                   'usage', 'productDisplayName']
user_df = pd.read_csv("datasets/fashion/user.csv")

# %%
def data_info_gen():
    out = open('out.txt','a')
    for item in fashion_dat[1:]:
        out.write('\r')
        out.write(str(fashion_df[f'{item}'].value_counts()))
        out.write('\r')
    return 'Success'
    
data_info_gen()
# Out:
# 'Success'

# %%
def hist_gen():
    for tuple in fashion_df.items():
        if tuple[0] != "id":
            plt.figure(figsize=(20,5))
            plt.hist(tuple,bins=len(fashion_df[f'{tuple[0]}'].unique()))
         
        
            
#             plt.savefig(f'datasets/fashion/hist_dat/{tuple[0]}')
            plt.show()
            plt.clf()

hist_gen()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\users\hassa\pycharmprojects\recommender_systems_notes\venv\lib\site-packages\matplotlib\axis.py:1665, in Axis.convert_units(self, x)
#    1664 try:
# -> 1665     ret = self.converter.convert(x, self.units, self)
#    1666 except Exception as e:
#
# File c:\users\hassa\pycharmprojects\recommender_systems_notes\venv\lib\site-packages\matplotlib\category.py:68, in StrCategoryConverter.convert(value, unit, axis)
#      67 # force an update so it also does type checking
# ---> 68 unit.update(values)
#      69 return np.vectorize(unit._mapping.__getitem__, otypes=[float])(values)
#
# File c:\users\hassa\pycharmprojects\recommender_systems_notes\venv\lib\site-packages\matplotlib\category.py:227, in UnitData.update(self, data)
#     225 for val in OrderedDict.fromkeys(data):
#     226     # OrderedDict just iterates over unique values in data.
# --> 227     _api.check_isinstance((str, bytes), value=val)
#     228     if convertible:
#     229         # this will only be called so long as convertible is True.
#
# File c:\users\hassa\pycharmprojects\recommender_systems_notes\venv\lib\site-packages\matplotlib\_api\__init__.py:93, in check_isinstance(_types, **kwargs)
#      92     names.append("None")
# ---> 93 raise TypeError(
#      94     "{!r} must be an instance of {}, not a {}".format(
#      95         k,
#      96         ", ".join(names[:-1]) + " or " + names[-1]
#      97         if len(names) > 1 else names[0],
#      98         type_name(type(v))))
#
# TypeError: 'value' must be an instance of str or bytes, not a float
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# Cell In [35], line 13
#      10             plt.show()
#      11             plt.clf()
# ---> 13 hist_gen()
#
# Cell In [35], line 5, in hist_gen()
#       3         if tuple[0] != "id":
#       4             plt.figure(figsize=(20,5))
# ----> 5             plt.hist(tuple,bins=len(fashion_df[f'{tuple[0]}'].unique()))
#       9 #             plt.savefig(f'datasets/fashion/hist_dat/{tuple[0]}')
#      10             plt.show()
#
# File c:\users\hassa\pycharmprojects\recommender_systems_notes\venv\lib\site-packages\matplotlib\pyplot.py:2561, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2555 @_copy_docstring_and_deprecators(Axes.hist)
#    2556 def hist(
#    2557         x, bins=None, range=None, density=False, weights=None,
#    2558         cumulative=False, bottom=None, histtype='bar', align='mid',
#    2559         orientation='vertical', rwidth=None, log=False, color=None,
#    2560         label=None, stacked=False, *, data=None, **kwargs):
# -> 2561     return gca().hist(
#    2562         x, bins=bins, range=range, density=density, weights=weights,
#    2563         cumulative=cumulative, bottom=bottom, histtype=histtype,
#    2564         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2565         color=color, label=label, stacked=stacked,
#    2566         **({"data": data} if data is not None else {}), **kwargs)
#
# File c:\users\hassa\pycharmprojects\recommender_systems_notes\venv\lib\site-packages\matplotlib\__init__.py:1423, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1420 @functools.wraps(func)
#    1421 def inner(ax, *args, data=None, **kwargs):
#    1422     if data is None:
# -> 1423         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1425     bound = new_sig.bind(ax, *args, **kwargs)
#    1426     auto_label = (bound.arguments.get(label_namer)
#    1427                   or bound.kwargs.get(label_namer))
#
# File c:\users\hassa\pycharmprojects\recommender_systems_notes\venv\lib\site-packages\matplotlib\axes\_axes.py:6626, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6624 if orientation == "vertical":
#    6625     convert_units = self.convert_xunits
# -> 6626     x = [*self._process_unit_info([("x", x[0])], kwargs),
#    6627          *map(convert_units, x[1:])]
#    6628 else:  # horizontal
#    6629     convert_units = self.convert_yunits
#
# File c:\users\hassa\pycharmprojects\recommender_systems_notes\venv\lib\site-packages\matplotlib\artist.py:251, in Artist.convert_xunits(self, x)
#     249 if ax is None or ax.xaxis is None:
#     250     return x
# --> 251 return ax.xaxis.convert_units(x)
#
# File c:\users\hassa\pycharmprojects\recommender_systems_notes\venv\lib\site-packages\matplotlib\axis.py:1667, in Axis.convert_units(self, x)
#    1665     ret = self.converter.convert(x, self.units, self)
#    1666 except Exception as e:
# -> 1667     raise munits.ConversionError('Failed to convert value(s) to axis '
#    1668                                  f'units: {x!r}') from e
#    1669 return ret
#
# ConversionError: Failed to convert value(s) to axis units: array(['Navy Blue', 'Blue', 'Silver', ..., 'Blue', 'Blue', 'Pink'],
#       dtype=object)

# %%
def random_recommender(u):
    print(random.choice(fashion_df['id'].values))
    


users = user_df['id'].values     
for user in users:S
    random_recommender(user)
# Out:
# 6533
# 20518
# 18512
# 36126
# 3681
